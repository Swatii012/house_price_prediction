# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# dataset
df = pd.read_csv('/content/realest.csv')

# %%
df.head()
# Out:
#    Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0   53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1   55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2   56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3   58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4   64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0

# %%
# data shape
df.shape
# Out:
# (157, 9)

# %%
# data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      156 non-null    float64
#  1   Bedroom    156 non-null    float64
#  2   Space      146 non-null    float64
#  3   Room       156 non-null    float64
#  4   Lot        146 non-null    float64
#  5   Tax        147 non-null    float64
#  6   Bathroom   156 non-null    float64
#  7   Garage     156 non-null    float64
#  8   Condition  156 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
# check duplicated data
df.duplicated().sum()
# Out:
# 0

# %%
# check null value
df.isnull().sum()
# Out:
# Price         1
# Bedroom       1
# Space        11
# Room          1
# Lot          11
# Tax          10
# Bathroom      1
# Garage        1
# Condition     1
# dtype: int64

# %%
df
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# 5     44.0      4.0   897.0   7.0  25.0   960.0       2.0     1.0        0.0
# 6     49.0      5.0  1400.0   8.0   NaN   678.0       1.0     1.0        1.0
# 7     70.0      3.0  2261.0   6.0  29.0  2700.0       1.0     2.0        0.0
# 8     72.0      4.0  1290.0   8.0   NaN   800.0       1.5     1.5        0.0
# 9     82.0      4.0  2104.0   9.0  40.0  1038.0       2.5     1.0        1.0
# 10    85.0      8.0  2240.0  12.0  50.0  1200.0       3.0     2.0        0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      156 non-null    float64
#  1   Bedroom    156 non-null    float64
#  2   Space      146 non-null    float64
#  3   Room       156 non-null    float64
#  4   Lot        146 non-null    float64
#  5   Tax        147 non-null    float64
#  6   Bathroom   156 non-null    float64
#  7   Garage     156 non-null    float64
#  8   Condition  156 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
# remove null data
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      128 non-null    float64
#  1   Bedroom    128 non-null    float64
#  2   Space      128 non-null    float64
#  3   Room       128 non-null    float64
#  4   Lot        128 non-null    float64
#  5   Tax        128 non-null    float64
#  6   Bathroom   128 non-null    float64
#  7   Garage     128 non-null    float64
#  8   Condition  128 non-null    float64
# dtypes: float64(9)
# memory usage: 10.0 KB

# %%
df
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# 5     44.0      4.0   897.0   7.0  25.0   960.0       2.0     1.0        0.0
# 7     70.0      3.0  2261.0   6.0  29.0  2700.0       1.0     2.0        0.0
# 9     82.0      4.0  2104.0   9.0  40.0  1038.0       2.5     1.0        1.0
# 10    85.0      8.0  2240.0  12.0  50.0  1200.0       3.0     2.0        0.0
# 11    45.0      2.0   641.0   5.0  25.0   860.0       1.0     0.0        0.0
# 12    47.0      3.0   862.0   6.0  25.0   600.0       1.0     0.0        0.0
# ...

# %%
# check null value
df.isnull().sum()
# Out:
# Price        0
# Bedroom      0
# Space        0
# Room         0
# Lot          0
# Tax          0
# Bathroom     0
# Garage       0
# Condition    0
# dtype: int64

# %%
# changing data type
df['Bedroom'] = df['Bedroom'].astype('int64')
df['Room'] = df['Room'].astype('int64')

# %%
df
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0        2   967.0     5  39.0   652.0       1.5     0.0        0.0
# 1     55.0        2   815.0     5  33.0  1000.0       1.0     2.0        1.0
# 2     56.0        3   900.0     5  35.0   897.0       1.5     1.0        0.0
# 3     58.0        3  1007.0     6  24.0   964.0       1.5     2.0        0.0
# 4     64.0        3  1100.0     7  50.0  1099.0       1.5     1.5        0.0
# 5     44.0        4   897.0     7  25.0   960.0       2.0     1.0        0.0
# 7     70.0        3  2261.0     6  29.0  2700.0       1.0     2.0        0.0
# 9     82.0        4  2104.0     9  40.0  1038.0       2.5     1.0        1.0
# 10    85.0        8  2240.0    12  50.0  1200.0       3.0     2.0        0.0
# 11    45.0        2   641.0     5  25.0   860.0       1.0     0.0        0.0
# 12    47.0        3   862.0     6  25.0   600.0       1.0     0.0        0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      128 non-null    float64
#  1   Bedroom    128 non-null    int64
#  2   Space      128 non-null    float64
#  3   Room       128 non-null    int64
#  4   Lot        128 non-null    float64
#  5   Tax        128 non-null    float64
#  6   Bathroom   128 non-null    float64
#  7   Garage     128 non-null    float64
#  8   Condition  128 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 10.0 KB

# %%
# deleting column condition
df.drop(columns=['Condition'],inplace=True)

# %%
df
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage
# 0     53.0        2   967.0     5  39.0   652.0       1.5     0.0
# 1     55.0        2   815.0     5  33.0  1000.0       1.0     2.0
# 2     56.0        3   900.0     5  35.0   897.0       1.5     1.0
# 3     58.0        3  1007.0     6  24.0   964.0       1.5     2.0
# 4     64.0        3  1100.0     7  50.0  1099.0       1.5     1.5
# 5     44.0        4   897.0     7  25.0   960.0       2.0     1.0
# 7     70.0        3  2261.0     6  29.0  2700.0       1.0     2.0
# 9     82.0        4  2104.0     9  40.0  1038.0       2.5     1.0
# 10    85.0        8  2240.0    12  50.0  1200.0       3.0     2.0
# 11    45.0        2   641.0     5  25.0   860.0       1.0     0.0
# 12    47.0        3   862.0     6  25.0   600.0       1.0     0.0
# 13    49.0        4  1043.0     7  30.0   676.0       1.5     0.0
# 14    56.0        4  1325.0     8  50.0  1287.0       1.5     0.0
# ...

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-116-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Bedroom'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Bedroom'>

# %%
sns.distplot(df['Space'])
# Out:
# <ipython-input-118-203ba1be3d3b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Space'])
# <Axes: xlabel='Space', ylabel='Density'>

# %%
df['Room'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Room'>

# %%
sns.barplot(x=df['Lot'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['Room'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Room'],y=df['Price'])
# Out:
# <Axes: xlabel='Room', ylabel='Price'>

# %%
df['Room'].value_counts()
# Out:
# Room
# 5     41
# 7     31
# 6     26
# 8     15
# 9      6
# 12     6
# 4      3
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage
# 31    46.0        3   855.0     7  25.0   948.0       2.0     1.0
# 155   62.0        4   951.0     7  30.0   895.0       2.0     1.0
# 57    44.0        4   880.0     7  25.0   965.0       2.0     1.0
# 0     53.0        2   967.0     5  39.0   652.0       1.5     0.0
# 64    47.0        4   924.0     6  25.0   633.0       1.0     0.0
# 126   49.0        3   758.0     5  27.0   766.0       1.0     0.0
# 12    47.0        3   862.0     6  25.0   600.0       1.0     0.0
# 116   44.0        3   914.0     6  25.0   544.0       1.0     0.0
# 138   70.0        3  1250.0     8  33.0   851.0       1.5     1.5
# 118   57.0        5  1198.0     8  50.0  1244.0       1.5     0.0

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.distplot((df['Price']))
# Out:
# <ipython-input-126-6a4a02669d9f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-127-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Bedroom   Space  Room   Lot     Tax  Bathroom  Garage
# 0          2   967.0     5  39.0   652.0       1.5     0.0
# 1          2   815.0     5  33.0  1000.0       1.0     2.0
# 2          3   900.0     5  35.0   897.0       1.5     1.0
# 3          3  1007.0     6  24.0   964.0       1.5     2.0
# 4          3  1100.0     7  50.0  1099.0       1.5     1.5
# 5          4   897.0     7  25.0   960.0       2.0     1.0
# 7          3  2261.0     6  29.0  2700.0       1.0     2.0
# 9          4  2104.0     9  40.0  1038.0       2.5     1.0
# 10         8  2240.0    12  50.0  1200.0       3.0     2.0
# 11         2   641.0     5  25.0   860.0       1.0     0.0
# 12         3   862.0     6  25.0   600.0       1.0     0.0
# 13         4  1043.0     7  30.0   676.0       1.5     0.0
# 14         4  1325.0     8  50.0  1287.0       1.5     0.0
# 15         2   782.0     5  25.0   834.0       1.0     0.0
# 16         3  1126.0     7  30.0   734.0       2.0     0.0
# ...

# %%
y
# Out:
# 0      3.970292
# 1      4.007333
# 2      4.025352
# 3      4.060443
# 4      4.158883
# 5      3.784190
# 7      4.248495
# 9      4.406719
# 10     4.442651
# 11     3.806662
# 12     3.850148
# 13     3.891820
# 14     4.025352
# 15     4.094345
# 16     4.127134
# 18     4.189655
# 19     3.555348
# 20     3.637586
# 22     3.828641
# 23     3.828641
# 24     3.912023
# 25     4.174387
# 26     3.988984
# 27     4.060443
# 28     4.060443
# 29     4.110874
# 30     4.127134
# 31     3.828641
# 33     4.248495
# 34     4.276666
# 35     4.394449
# 36     4.477337
# 37     3.806662
# 38     3.850148
# 39     3.850148
# 40     4.007333
# 41     4.110874
# 42     4.158883
# 43     4.174387
# 44     4.158883
# 45     3.555348
# 46     3.583519
# 47     3.737670
# 48     3.871201
# 50     3.970292
# 51     4.189655
# 53     4.043051
# 54     4.077537
# 55     4.025352
# 57     3.784190
# 58     3.931826
# 59     4.248495
# 60     4.248495
# 61     4.430817
# 62     4.442651
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Bedroom'}>,
#         <Axes: title={'center': 'Space'}>,
#         <Axes: title={'center': 'Room'}>],
#        [<Axes: title={'center': 'Lot'}>, <Axes: title={'center': 'Tax'}>,
#         <Axes: title={'center': 'Bathroom'}>],
#        [<Axes: title={'center': 'Garage'}>, <Axes: >, <Axes: >]],
#       dtype=object)
